# %% [markdown]
# # Assignment14

# %% [markdown]
# # Q1. What does RGBA stand for?
# Red Green Blue Alpha (RGBA)

# %% [markdown]
# # Q2 From the Pillow module, how do you get the RGBA value of any images?
# from PIL import Image
# Image.getdata()

# %% [markdown]
# # Q3 What is a box tuple, and how does it work?
# Tuple is arrangement of 4 coordinates which are passed in many pillow function they represent four corners and form a rectangular box. They are in order left, top,right,bottom

# %% [markdown]
# # Q4 Use your image and load in notebook then, How can you find out the width and height of an Image object?

# %%
from PIL import Image
image1 = Image.open('16461177506211.jpg')
print(image1.size)
# Out:
# (500, 250)

# %% [markdown]
# # Q5 What method would you call to get Image object for a 100×100 image, excluding the lower-left quarter of it?

# %%
from PIL import Image
from matplotlib import pyplot as plt
# %matplotlib inline


import numpy as np
import cv2

image = cv2.imread('16461177506211.jpg')

y=125
x=0
h=125
w=250

crop = image[y:y+h, x:x+w]
image[y:y+h, x:x+w] = (0, 0, 0)
cv2.imshow('Image', image)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()
# display(a)
# cv2.waitKey(0)
# Out:
# (500, 250)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x250>

# %% [markdown]
# # Q6. After making changes to an Image object, how could you save it as an image file?

# %% [markdown]
# We will use:
# from PIL import Image
# Image.save() # This is the method to save a image object as an image file

# %% [markdown]
# # Q7. What module contains Pillow’s shape-drawing code?

# %% [markdown]
# ImageDraw module

# %% [markdown]
# # Q8. Image objects do not have drawing methods. What kind of object does? How do you get this kind of object?

# %% [markdown]
# Draw object has drawing methods
#
# ## It can be created using the below code:
# from PIL import Image, ImageDraw
#
# img = Image.open('img_path.png')
#
# draw = ImageDraw.Draw(img)
